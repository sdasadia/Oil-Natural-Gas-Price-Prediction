# %%
install.packages('fGarch')
# Out:
# Installing package into ‘/Users/sarthakdasadia/Library/R/3.3/library’
# (as ‘lib’ is unspecified)

# %%
options(warn=-1)

library(xts)
library(Quandl)
library(dplyr)
library(plotly)
library(lubridate)
library(forecast)
library(TSPred)
library(fGarch)
library(tseries)

# %% [markdown]
# ### Dowload data using Quandl API
#
# - The API will provide weekly data since 04/08/1990
# - It will form a dataframe which needs to be reversed to in chronological order

# %%
qurtly_data = Quandl("CHRIS/CME_NG1", collapse = 'quarterly')
monthly_data = Quandl("CHRIS/CME_NG1", collapse = 'monthly')
weekly_data = Quandl("CHRIS/CME_NG1", collapse = 'weekly')
daily_data = Quandl("CHRIS/CME_NG1", collapse = 'daily')

# %%
qurtly_data <- qurtly_data[rev(rownames(qurtly_data)),]
monthly_data <- monthly_data[rev(rownames(monthly_data)),]
weekly_data <- weekly_data[rev(rownames(weekly_data)),]
daily_data <- daily_data[rev(rownames(daily_data)),]

# %%
head(qurtly_data)
# Out:
#     Date       Open  High  Low   Last  Change Settle Volume
# 109 1990-06-30 1.510 1.519 1.510 1.519 NA     1.519   80
# 108 1990-09-30 1.940 1.960 1.935 1.935 NA     1.935  159
# 107 1990-12-31 1.960 1.960 1.945 1.950 NA     1.950   23
# 106 1991-03-31 1.396 1.405 1.396 1.405 NA     1.405  143
# 105 1991-06-30 1.190 1.220 1.160 1.208 NA     1.208  600
# 104 1991-09-30 1.922 1.938 1.922 1.935 NA     1.935   95
#     Previous Day Open Interest
# 109  467
# 108 1187
# 107 1673
# 106 1428
# 105 1281
# 104 2972

# %%
tail(qurtly_data)
# Out:
#   Date       Open  High  Low   Last  Change Settle Volume
# 6 2016-03-31 1.990 2.028 1.930 1.963 0.037  1.959  182878
# 5 2016-06-30 2.863 2.945 2.851 2.934 0.061  2.924  160100
# 4 2016-09-30 2.966 2.977 2.892 2.903 0.053  2.906  165713
# 3 2016-12-31 3.800 3.857 3.690 3.744 0.078  3.724   96294
# 2 2017-03-31 3.199 3.242 3.163 3.192 0.001  3.190  112343
# 1 2017-06-30 3.049 3.060 3.012 3.020 0.010  3.037   44524
#   Previous Day Open Interest
# 6 341940
# 5 215017
# 4 288471
# 3 169719
# 2 308378
# 1  21360

# %%
dim(qurtly_data)
dim(monthly_data)
dim(daily_data)
# Out:
# [1] 109   9
# [1] 327   9
# [1] 6827    9

# %%
p1 <- plot_ly(daily_data, x = ~Date, y = ~Open, type = 'scatter', mode = 'lines') %>%
        layout(title = "Natural Gas Prices Chart",
         xaxis = list(title = "Year"),
         yaxis = list (title = "Price in US$ per Million BTU"))
p1
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ### Convert the dataframe into a time series and check properties

# %%
qurtly_ts <- ts(qurtly_data$Open, frequency=4, start = decimal_date(ymd("1990-06-30")))
monthly_ts <- ts(log(monthly_data$Open))
daily_ts <- ts(log(daily_data$Open))

#gas_ts <- ts(log(gas_data$Open), frequency=12, start=decimal_date(ymd("1990-04-30")))

# %%
# Decompose time series

decomp = stl(qurtly_ts, s.window="periodic")
plot(decomp)
# Out:
# plot without title

# %% [markdown]
# We clearely see seasonality in the residual plot. For Time Series analysis, we need to convert it into a stationary series.
#
# The ***augmented Dickey-Fuller (ADF)*** test is a formal statistical test for stationarity. The null hypothesis assumes that the series is non-stationary. ADF procedure tests whether the change in Y can be explained by lagged value and a linear trend. If contribution of the lagged value to the change in Y is non-significant and there is a presence of a trend component, the series is non-stationary and null hypothesis will not be rejected.

# %%
adf.test(qurtly_ts, alternative = "stationary")
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  qurtly_ts
# Dickey-Fuller = -1.7956, Lag order = 4, p-value = 0.6614
# alternative hypothesis: stationary

# %% [markdown]
# This means that the series is not stationary. Usually, non-stationary series can be corrected by a simple transformation such as differencing. Differencing the series can help in removing its trend or cycles. The idea behind differencing is that, if the original data series does not have constant properties over time, then the change from one period to another might.

# %%
qurtly_dff1 = diff(qurtly_ts, differences = 1)
adf.test(qurtly_dff1, alternative = "stationary")

plot(qurtly_dff1, ylab="Residual")
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  qurtly_dff1
# Dickey-Fuller = -6.1425, Lag order = 4, p-value = 0.01
# alternative hypothesis: stationary
# plot without title

# %%
summary(qurtly_dff1)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -6.0840 -0.4763  0.0480  0.0137  0.5268  7.0040

# %% [markdown]
# The mean is close to 0 and Dickey-Fuller Test suggests that the null hypothesis can be rejected. That is TS is close to being a stationary and differencing parameter ***d = 1***

# %% [markdown]
# *** Autocorrelations and Choosing Model Order ***
#
# Autocorrelation plots (also known as ACF or the auto correlation function) are a useful visual tool in determining whether a series is stationary. These plots can also help to choose the order parameters for ARIMA model. If the series is correlated with its lags then, generally, there are some trend or seasonal components and therefore its statistical properties are not constant over time.
#
# ACF plots display correlation between a series and its lags. In addition to suggesting the order of differencing, ACF plots can help in determining the order of the MA (q) model. Partial autocorrelation plots (PACF), as the name suggests, display correlation between a variable and its lags that is not explained by previous lags. PACF plots are useful when determining the order of the AR(p) model.

# %%
# Inspect ACF and PACF

ggtsdisplay(qurtly_ts)
# Out:
# plot without title

# %% [markdown]
# #### Auto-correlation of residual

# %%
ggtsdisplay(qurtly_dff1)
# Out:
# plot without title

# %% [markdown]
# There are significant auto correlations at lag 3 and 11 and beyond. Partial correlation plots show a significant spike at lag 3 and 9. This suggests that we might want to test models with AR or MA components of order 3, 9, or 11. A spike at lag 3 might suggest that there is a seasonal pattern present, perhaps a season in a year.

# %%
fit_qurtly = arima(qurtly_ts, order=c(11,1,3))
fit_qurtly

tsdisplay(residuals(fit_qurtly), lag.max=15, main='Model Residuals')
# Out:
# Call:
# arima(x = qurtly_ts, order = c(11, 1, 3))
#
# Coefficients:
#           ar1      ar2     ar3      ar4      ar5     ar6    ar7      ar8
#       -0.3641  -0.2147  0.2839  -0.1840  -0.0326  0.0568  0.038  -0.0652
# s.e.   0.2104   0.2272  0.2351   0.1527   0.1613  0.1475  0.127   0.1165
#           ar9    ar10    ar11     ma1     ma2      ma3
#       -0.0296  0.1961  0.2732  0.1946  0.0435  -0.6926
# s.e.   0.1120  0.1110  0.0963  0.2050  0.1983   0.1823
#
# sigma^2 estimated as 1.414:  log likelihood = -173.18,  aic = 376.37
# Plot with title “”

# %%
fcast_qurtly <- forecast(fit_qurtly, h=10)
plot(fcast_qurtly)
# Out:
# Plot with title “Forecasts from ARIMA(11,1,3)”

# %%
fcast_qurtly
# Out:
#          Point Forecast     Lo 80    Hi 80     Lo 95    Hi 95
# 2017.743      0.9402757 0.6728114 1.207740 0.5312244 1.349327
# 2017.993      0.9286013 0.5734336 1.283769 0.3854192 1.471783
# 2018.243      0.9507726 0.5431052 1.358440 0.3272991 1.574246
# 2018.493      0.9085867 0.4786800 1.338493 0.2511012 1.566072
# 2018.743      0.8523306 0.4058557 1.298806 0.1695061 1.535155
# 2018.993      0.8508905 0.3933117 1.308469 0.1510841 1.550697
# 2019.243      0.9274523 0.4596101 1.395294 0.2119494 1.642955
# 2019.493      0.9616680 0.4768863 1.446450 0.2202583 1.703078
# 2019.743      1.0613265 0.5632460 1.559407 0.2995782 1.823075
# 2019.993      0.9857476 0.4799106 1.491585 0.2121366 1.759359

# %% [markdown]
# # Exponential Smoothing

# %%
exp_model <- HoltWinters(qurtly_ts, beta = FALSE)

exp_model
# Out:
# Holt-Winters exponential smoothing without trend and with additive seasonal component.
#
# Call:
# HoltWinters(x = qurtly_ts, beta = FALSE)
#
# Smoothing parameters:
#  alpha: 0.8673124
#  beta : FALSE
#  gamma: 0.1626544
#
# Coefficients:
#          [,1]
# a   3.2958885
# s1  0.1526457
# s2  0.2823822
# s3 -0.1584791
# s4 -0.2377994

# %%
exp_pred <- predict(exp_model, 5, prediction.interval = TRUE)
exp_pred
# Out:
#      fit      upr      lwr
# [1,] 3.448534 6.277541  0.6195273
# [2,] 3.578271 7.323080 -0.1665381
# [3,] 3.137409 7.614452 -1.3396328
# [4,] 3.058089 8.163402 -2.0472238
# [5,] 3.448534 9.139569 -2.2425010

# %%
plot.ts(qurtly_ts, ylab = "Gas Price", xlim = c(1985, 2025))
lines(exp_model$fitted[,1], col = "green")
lines(exp_pred[,1], col = "blue")
lines(exp_pred[,2], col = "red", lty = 2)
lines(exp_pred[,2], col = "red", lty = 2)
# Out:
# plot without title

# %%
auto.arima(qurtly_ts, seasonal=TRUE)
# Out:
# Series: qurtly_ts
# ARIMA(2,1,2)
#
# Coefficients:
#          ar1      ar2      ma1     ma2
#       1.5362  -0.7066  -1.7745  0.8596
# s.e.  0.2751   0.1602   0.2950  0.2688
#
# sigma^2 estimated as 1.735:  log likelihood=-181.38
# AIC=372.75   AICc=373.34   BIC=386.16

# %%
# Splitting data into training and test 

training <- window(gas_ts, start=1, end=320) 
test <- window(gas_ts, start = 321, end=335) 

model <- arima(training, order=c(9,1,5))
#model2 <- garchFit(training, order=c(1,1))
summary(model)
# Out:
# Call:
# arima(x = training, order = c(9, 1, 5))
#
# Coefficients:
#          ar1      ar2      ar3     ar4      ar5     ar6      ar7      ar8
#       0.4280  -0.7114  -0.5900  0.2386  -0.8437  0.1173  -0.2153  -0.1135
# s.e.  0.1612   0.1742   0.2198  0.1830   0.1309  0.0866   0.0728   0.0744
#           ar9      ma1     ma2     ma3      ma4     ma5
#       -0.0288  -0.4429  0.5897  0.6914  -0.3491  0.7853
# s.e.   0.0697   0.1509  0.1661  0.1995   0.1583  0.1045
#
# sigma^2 estimated as 0.01866:  log likelihood = 181.04,  aic = -332.08
#
# Training set error measures:
#                       ME      RMSE       MAE       MPE     MAPE      MASE
# Training set 0.002533849 0.1363912 0.1070368 -1.229865 11.34235 0.9391443
#                      ACF1
# Training set 0.0002200959

# %%
model <- auto.arima(training, trace = TRUE, test = 'kpss', ic = 'aic', seasonal=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : -308.3488
#  ARIMA(0,1,0) with drift         : -301.7974
#  ARIMA(1,1,0) with drift         : -299.3179
#  ARIMA(0,1,1) with drift         : -300.6074
#  ARIMA(0,1,0)                    : -303.7171
#  ARIMA(1,1,2) with drift         : -309.302
#  ARIMA(1,1,1) with drift         : -302.004
#  ARIMA(1,1,3) with drift         : -310.4001
#  ARIMA(0,1,2) with drift         : -309.7751
#  ARIMA(2,1,4) with drift         : -304.9418
#  ARIMA(1,1,3)                    : -312.1074
#  ARIMA(0,1,3)                    : -310.087
#  ARIMA(2,1,3)                    : -308.2415
#  ARIMA(1,1,2)                    : -311.0321
#  ARIMA(1,1,4)                    : -310.1504
#  ARIMA(0,1,2)                    : -311.6634
#  ARIMA(2,1,4)                    : -306.5527
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(1,1,3)                    : -316.5969
#
#  Best model: ARIMA(1,1,3)

# %%
plotarimapred(test, model, xlim=c(300, 340), range.percent = 0.05)
# Out:
# Plot with title “Forecasts from ARIMA(1,1,3)”
